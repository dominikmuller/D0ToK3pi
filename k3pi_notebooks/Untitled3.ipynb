# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline
from k3pi_config.modes import MODE
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-67aad3622719> in <module>()
#       1 get_ipython().magic(u"config InlineBackend.figure_format='retina'")
#       2 get_ipython().magic(u'matplotlib inline')
# ----> 3 from k3pi_config.modes import MODE
#
# /afs/cern.ch/work/d/dmuller/K3Pi/repository/k3pi_config/__init__.py in <module>()
# ----> 1 from . import config,  modes
#       2
#       3 __all__ = [config, modes]
#       4
#       5 def get_mode(polarity, year, mode):
#
# /afs/cern.ch/work/d/dmuller/K3Pi/repository/k3pi_config/modes/__init__.py in <module>()
# ----> 1 from .D0ToKpipipi_RS import D0ToKpipipi_RS
#       2 from .D0ToKpipipi_WS import D0ToKpipipi_WS
#       3 from .D0ToKpipipi_2tag_RS import D0ToKpipipi_2tag_RS
#       4 from .D0ToKpipipi_2tag_WS import D0ToKpipipi_2tag_WS
#       5 from .mode_base import ModeConfig
#
# ...

# %%
update_level(log.DEBUG)

# %%
with MODE('MagBoth', 2015, 'RS', 'mc'):
    df = gcm().get_data([vars.m(gcm().D0), vars.dtf_dm(), vars.dtf_chi2(gcm().head)])
    sel = selection.full_selection()
# Out:
# DEBUG:pid_selection:Looked up RSmc -> loading [Pi_SS_MC15TuneV1_ProbNNpi, K_MC15TuneV1_ProbNNk, Pi_OS2_MC15TuneV1_ProbNNk, Pi_OS2_MC15TuneV1_ProbNNpi, Pi_SS_MC15TuneV1_ProbNNk, Pi_OS1_MC15TuneV1_ProbNNk, Pi_OS1_MC15TuneV1_ProbNNpi, K_MC15TuneV1_ProbNNpi]
# DEBUG:pid_fiducial_selection:Looked up RSmc -> loading [K_P, Pi_OS1_ETA, Pi_OS1_P, Pi_OS2_ETA, Pi_SS_ETA, Pi_OS2_P, Pi_SS_P, K_ETA]
# DEBUG:mass_fiducial_selection:Looked up RSmc -> loading [D0_M, delta_m_dtf]
# DEBUG:remove_secondary:Looked up RSmc -> loading [D0_Loki_BPVIPCHI2]
# DEBUG:slow_pion:Looked up RSmc -> loading [Pislow_MC15TuneV1_ProbNNghost, Pislow_MC15TuneV1_ProbNNmu, Pislow_MC15TuneV1_ProbNNk, Pislow_MC15TuneV1_ProbNNpi]

# %%
with MODE('MagBoth', 2015, 'RS', 'mc'):
    plt.hist(df[vars.m(gcm().D0)][sel], bins=50);

# %%
with MODE('MagBoth', 2015, 'RS'):
    print gcm().mode
# Out:
# D0ToKpipipi_RS

# %%
sum(sel)/3500000.
# Out:
# 0.0017725714285714285

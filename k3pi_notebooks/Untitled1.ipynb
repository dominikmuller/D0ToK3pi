# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline

# %%
from k3pi_config.modes import MODE
from analysis import bdt_studies, selection
import matplotlib.pyplot as plt

# %%
with MODE('MagBoth', 2015, 'RS'):
    bdt = bdt_studies.get_bdt_discriminant()
    sel = selection.full_selection()

# %%
plt.hist(bdt, bins=100,range=(0, 1));

# %%
bdt.max()
# Out:
# 0.84904713950096689

# %%
print mode.K
print dtf_pt(mode.K)
print dtf_pt.latex(mode.K)
print dtf_pt.latex(mode.K, with_unit=True)
# Out:
# Particle(name='K', title='$K^{-}$', daughters=[])
# Dstp_DTFDict_K_PT
# DTF $p_{\text{T}}(K^{-})$
# DTF $p_{\text{T}}(K^{-})$ [${\mathrm{\,Me\kern -0.1em V\!/}c}$]

# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline
import root_pandas
from k3pi_config import config
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from k3pi_cpp import (vec_phsp_variables, t_gen_phasespaced)
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
from k3pi_utilities import logger
logger.update_level(logger.logging.DEBUG)
from analysis import phsp_generator

# %%
from k3pi_config import filelists
paths = filelists.Generated.paths
import root_pandas
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
df = root_pandas.read_root(paths)

# %%
df.rename(columns={'c12': 'cos1', 'c34':'cos2', 'dtime':'D0_Loki_BPVLTIME', 'phi':'phi1'}, inplace=True)

# %%
df
# Out:
#               m12       m34      cos1      cos2      phi1  D0_Loki_BPVLTIME
# 0        0.297886  0.837078 -0.180292 -0.634516 -2.042346          1.384505
# 1        0.378817  1.366315  0.114553  0.772256 -2.325993          0.240165
# 2        0.668038  0.827992  0.380154 -0.399290 -2.635052          0.221687
# 3        0.422545  0.943559  0.141318 -0.804644 -2.948242          0.042386
# 4        0.861002  0.888133  0.382087 -0.290931 -2.949643          0.540500
# 5        0.814155  0.859488  0.933545 -0.700501 -1.900520          0.368188
# 6        0.906390  0.864154  0.526883  0.507521 -0.410902          0.651188
# 7        0.587051  0.877515 -0.532234 -0.099775  0.037749          0.151638
# 8        0.641426  1.154161 -0.076326 -0.670627 -1.057508          0.325120
# 9        1.049392  0.697683  0.969059 -0.786821  2.731990          0.784546
# 10       0.462368  1.269061 -0.215397  0.410258  1.376751          0.072424
# ...
